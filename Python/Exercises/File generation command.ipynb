# %% [markdown]
# # Python Basics

# %%
import nbformat

questions = [
    "Print \"Hello, World!\" using Python.",
    "Declare a variable `x` and assign it the value 5.",
    "Print the value of `x`.",
    "What is the difference between single and double quotes in Python?",
    "Create a list with elements: 1, 2, 3, 4, 5.",
    "Access and print the third element of the list.",
    "Add a new element (6) to the list.",
    "Create a tuple with elements: 'apple', 'banana', 'cherry'.",
    "What is the key difference between a list and a tuple?",
    "Declare a dictionary with keys: 'name', 'age', 'city' and corresponding values.",
    "Print only the keys of the dictionary.",
    "Print only the values of the dictionary.",
    "Create a function `add_numbers` that takes two parameters and returns their sum.",
    "Call the function `add_numbers` with arguments 3 and 7.",
    "Define a conditional statement that prints \"Even\" if a number is even and \"Odd\" if it's odd.",
    "Use a loop to print numbers from 1 to 5.",
    "Create a list comprehension to generate a list of squares of numbers from 1 to 5.",
    "Define a class `Person` with attributes name and age.",
    "Create an instance of the `Person` class with the name 'John' and age 25.",
    "Print the name and age of the person instance.",
    "Import the `math` module and use it to calculate the square root of 16.",
    "What is the purpose of the `if __name__ == \"__main__\":` statement in Python?",
    "Write a file named 'example.txt' with the content \"Hello, file handling!\".",
    "Read the content of 'example.txt' and print it.",
    "Handle an exception for reading a non-existing file and print a custom error message.",
    "Use a `while` loop to print numbers from 1 to 3.",
    "Create a function that takes a list as a parameter and returns the sum of its elements.",
    "Sort the list [5, 2, 8, 1, 3] in ascending order.",
    "Reverse the order of the elements in the sorted list.",
    "Create a set with elements: 1, 2, 3, 4, 5.",
    "Add an element (6) to the set.",
    "Remove an element (3) from the set.",
    "Check if an element (4) is present in the set.",
    "Use a for loop to iterate over the elements of the set and print them.",
    "Define a lambda function that adds two numbers and use it to add 3 and 4.",
    "What is the purpose of the `pass` statement in Python?",
    "Convert the string \"123\" to an integer.",
    "Convert the integer 456 to a string.",
    "Slice the string \"Hello, World!\" to get only \"Hello\".",
    "Concatenate the strings \"Hello\" and \"World!\".",
    "Find the length of the string \"Python\".",
    "Replace the word \"old\" with \"new\" in the string \"An old book\".",
    "Convert the string \"3.14\" to a floating-point number.",
    "Use a list slice to get the last three elements of a list.",
    "Check if a number is positive, negative, or zero using if-elif-else statements.",
    "Write a function that returns the factorial of a given number.",
    "Create a module named `calculator` with functions for addition, subtraction, multiplication, and division.",
    "Import the `calculator` module and use its functions to perform arithmetic operations.",
    "Define a generator function that yields square numbers up to a given limit.",
    "Use a list comprehension to create a list of even numbers from 1 to 10.",
    "Create a module with a function that takes a CSV file path and returns a list of dictionaries.",
    "Use a `try-except` block to handle division by zero and print an error message.",
    "Use the `enumerate` function to iterate over a list and print both index and value.",
    "Write a regular expression to match email addresses.",
    "Use the `random` module to generate a random number between 1 and 10.",
    "Use the `map` function to square each element in a list.",
    "Create a module with a function that generates a Fibonacci sequence up to a given limit.",
    "Write a script that reads a CSV file and prints the average of a specific column.",
    "Use the `collections` module to create a Counter for a list of elements.",
    "Write a function that takes a list and returns a new list with unique elements.",
    "Create a multi-line string and use triple quotes for its definition.",
    "Use the `logging` module to log a message with different log levels.",
    "Write a function that takes a list of integers and returns the sum of only positive numbers.",
    "Use the `heapq` module to find the three largest elements in a list.",
    "Create a class that implements the context manager protocol using `__enter__` and `__exit__` methods.",
    "Write a script that reads data from a URL using the `requests` library.",
    "Use the `re` module to search for a pattern in a string.",
    "Create a module with a function that takes two numbers and returns their quotient and remainder.",
    "Write a function that takes a list of strings and returns a new list with elements sorted in descending order.",
    "Use the `argparse` module to parse command line arguments in a script.",
    "Write a function that takes a list of strings and returns the longest string.",
    "Use the `itertools` module to generate all permutations of a list.",
    "Write a script that reads data from an API using the `requests` library.",
    "Create a function that takes a list of numbers and returns the median.",
    "Use the `os` module to check if a file exists before reading it.",
    "Write a function that takes a string and returns the number of vowels in it.",
    "Use the `subprocess` module to run an external command from a Python script.",
    "Create a class with a property that can be both get and set.",
    "Write a function that takes a list of strings and returns a new list with only unique strings.",
    "Use the `unittest` module to write a simple test case for a function.",
    "Write a script that logs messages to a file using the `logging` module.",
    "Create a class with a static method that performs a simple calculation.",
    "Write a script that uses the `pickle` module to serialize and deserialize an object."
]

# Create a new Jupyter notebook
notebook = nbformat.v4.new_notebook()

# Add a markdown cell at the beginning
notebook.cells.append(nbformat.v4.new_markdown_cell("# Python Practice Questions"))

# Add code cells for each question
for i, question in enumerate(questions, start=1):
    markdown_cell = nbformat.v4.new_markdown_cell(f"### Question {i}\n\n{question}")
    notebook.cells.append(markdown_cell)
    
    code_cell = nbformat.v4.new_code_cell("# My answer here")
    notebook.cells.append(code_cell)

# Save the notebook to a file
with open("python_practice_questions.ipynb", "w") as f:
    nbformat.write(notebook, f)

print("Jupyter notebook file created: python_practice_questions.ipynb")
# Out:
# Jupyter notebook file created: python_practice_questions.ipynb

# %%
import nbformat

sections = {
    "Strings and Lists": [
        "Create a function to reverse a string.",
        "Write a program to check if a given word is a palindrome.",
        "Given a list of numbers, find and print the maximum and minimum values."
    ],
    "Control Flow": [
        "Write a function to check if a number is prime.",
        "Implement a function to find the factorial of a number using recursion.",
        "Create a program that prints the Fibonacci sequence up to a certain limit."
    ],
    "Data Structures": [
        "Implement a stack using a Python list.",
        "Write a function to check if a given string has balanced parentheses.",
        "Create a dictionary and demonstrate how to iterate over its keys and values."
    ],
    "Functions and Modules": [
        "Define a function that takes two parameters and returns their sum.",
        "Create a module named `calculator` with functions for addition, subtraction, multiplication, and division."
    ],
    "File Handling": [
        "Write a script that reads a file, counts the number of lines, and prints the result.",
        "Create a CSV file with some data and write a Python program to read and print its content."
    ],
    "Exception Handling": [
        "Write a function that handles a division by zero exception and prints a meaningful message.",
        "Create a program that prompts the user for input and handles invalid inputs using try-except blocks."
    ],
    "Classes and OOP": [
        "Define a class `Car` with attributes `model` and `year`, and a method `display_info` that prints the car's information.",
        "Create a subclass `ElectricCar` that inherits from `Car` and adds a method to display battery information."
    ],
    "List Comprehensions": [
        "Use a list comprehension to create a list of squares of numbers from 1 to 10.",
        "Write a program to filter out even numbers from a given list using list comprehension."
    ],
    "Dictionaries and Sets": [
        "Create a dictionary representing a person with keys 'name', 'age', and 'city'.",
        "Write a program to remove duplicate elements from a list and convert it to a set."
    ],
    "Strings and Regular Expressions": [
        "Write a regular expression to match email addresses.",
        "Use string formatting to create a dynamic message with placeholders."
    ]
}

# Create a new Jupyter notebook
notebook = nbformat.v4.new_notebook()

# Add a markdown cell at the beginning
notebook.cells.append(nbformat.v4.new_markdown_cell("# Python Interview Practice Questions"))

# Add markdown cells for each section, question, and corresponding code cells
for section, questions in sections.items():
    notebook.cells.append(nbformat.v4.new_markdown_cell(f"## {section}"))
    
    for i, question in enumerate(questions, start=1):
        markdown_cell = nbformat.v4.new_markdown_cell(f"### {i}. {question}")
        notebook.cells.append(markdown_cell)
        
        code_cell = nbformat.v4.new_code_cell("# Your answer here")
        notebook.cells.append(code_cell)

# Save the notebook to a file
with open("python_interview_questions.ipynb", "w") as f:
    nbformat.write(notebook, f)

print("Jupyter notebook file created: python_interview_questions.ipynb")
# Out:
# Jupyter notebook file created: python_interview_questions.ipynb

# %%
import nbformat

sections = [
    ("Decorators", [
        "What is a decorator in Python?",
        "How do you define a decorator function?",
        "Explain the use of the @staticmethod decorator.",
        "How can you use a decorator to measure the execution time of a function?",
        "Differentiate between function-based and class-based decorators."
    ], [
        "Implement a timing decorator that measures the execution time of a function.",
        "Create a decorator that logs the parameters and return value of a function.",
        "Implement a memoization decorator to cache the results of a function."
    ]),
    ("Generators", [
        "What is a generator in Python?",
        "Explain the difference between a generator and a regular function.",
        "How do you create a generator function using the yield statement?",
        "What are the advantages of using generators over lists in terms of memory usage?",
        "Explain the concept of lazy evaluation in the context of generators."
    ], [
        "Write a generator function to generate the Fibonacci sequence up to a given limit.",
        "Create a generator that yields the powers of 2 indefinitely.",
        "Implement a generator that reads lines from a file and yields them one by one."
    ]),
    ("Context Managers", [
        "What is a context manager in Python?",
        "How do you create a context manager using the with statement?",
        "Explain the purpose of the __enter__ and __exit__ methods in a context manager.",
        "Provide an example of using the contextlib module to create a context manager.",
        "How can you create a custom context manager using a class."
    ], [
        "Create a context manager that measures the time it takes to execute a block of code.",
        "Implement a context manager for file handling that ensures proper closing of the file.",
        "Write a context manager that suppresses a specified exception within its block."
    ]),
    ("Metaclasses", [
        "What is a metaclass in Python?",
        "Explain the relationship between classes and metaclasses.",
        "How do you define a custom metaclass?",
        "Provide an example of using a metaclass to modify class behavior.",
        "What is the purpose of the __new__ and __init__ methods in a metaclass."
    ], [
        "Define a metaclass that ensures all class attributes are uppercase.",
        "Implement a metaclass that automatically adds a custom method to all classes it modifies.",
        "Write a metaclass that keeps track of the number of instances created for its classes."
    ]),
    ("Asynchronous Programming", [
        "What is asynchronous programming in Python?",
        "Explain the difference between synchronous and asynchronous code execution.",
        "How do you define an asynchronous function using async def?",
        "What is an event loop, and how does it relate to asynchronous programming?",
        "Provide an example of using the asyncio module for asynchronous programming."
    ], [
        "Create an asynchronous function that simulates parallel downloads of multiple URLs.",
        "Write an asynchronous program to fetch and process data from multiple APIs concurrently.",
        "Implement a simple asynchronous web scraper using aiohttp."
    ]),
    ("Coroutines", [
        "What is a coroutine in Python?",
        "How do you define a coroutine function?",
        "Explain the use of await in the context of coroutines.",
        "Compare coroutines to regular functions in terms of execution.",
        "How can you run multiple coroutines concurrently using asyncio.gather()?"
    ], [
        "Write a coroutine function to read lines from a file asynchronously.",
        "Create a program that uses coroutines to download web pages concurrently.",
        "Implement a coroutine that processes a stream of data and yields aggregated results."
    ]),
    ("Async/Await", [
        "What is the purpose of the async and await keywords?",
        "How do you handle exceptions in asynchronous code?",
        "Explain the concept of an asynchronous context manager.",
        "Provide an example of using asyncio.sleep() for asynchronous delays.",
        "What are the limitations of using asyncio for asynchronous programming?"
    ], [
        "Write an asynchronous function to handle multiple HTTP requests concurrently.",
        "Create an asynchronous program that simulates asynchronous I/O operations."
    ]),
    ("Concurrency", [
        "Differentiate between concurrency and parallelism.",
        "How can you achieve concurrent execution in Python using threads?",
        "Explain the Global Interpreter Lock (GIL) and its impact on concurrency.",
        "Compare the use of threads and asyncio for concurrent programming.",
        "Provide an example of using the concurrent.futures module for parallelism."
    ], [
        "Implement a program that uses threads to parallelize a CPU-bound task.",
        "Write a Python script that demonstrates the use of multiprocessing for parallelism.",
        "Create a program that uses concurrent futures to parallelize tasks."
    ]),
    ("Metaprogramming", [
        "What is metaprogramming in Python?",
        "Explain how decorators and metaclasses are forms of metaprogramming.",
        "Provide a use case for dynamically creating classes at runtime.",
        "How do you inspect and manipulate the attributes of a class programmatically?",
        "Explain the purpose of the __getattr__ and __setattr__ methods in metaprogramming."
    ], [
        "Write a decorator that validates the input types of a function.",
        "Implement a metaclass that enforces a naming convention for class attributes.",
        "Create a program that dynamically generates classes based on user input."
    ]),
    ("Dynamic Typing", [
        "What is dynamic typing in Python?",
        "Explain the difference between static typing and dynamic typing.",
        "How does dynamic typing contribute to the flexibility of Python code?",
        "Provide an example of using dynamic typing in a function.",
        "Discuss the advantages and disadvantages of dynamic typing in Python."
    ], [
        "Write a function that accepts arguments of any type and performs a specific operation.",
        "Implement a dynamic typing example where a variable changes its type during runtime.",
        "Create a program that dynamically extends a list with elements of different types."
    ])
]

# Create a new Jupyter notebook
notebook = nbformat.v4.new_notebook()

# Add a markdown cell at the beginning
notebook.cells.append(nbformat.v4.new_markdown_cell("# Advanced Python Practice Questions"))

# Loop through sections and questions to add markdown cells
for section_title, section_questions, section_coding_questions in sections:
    # Add section heading
    notebook.cells.append(nbformat.v4.new_markdown_cell(f"## {section_title}"))
    
    # Add theoretical questions
    for question in section_questions:
        notebook.cells.append(nbformat.v4.new_markdown_cell(question))
        
        code_cell = nbformat.v4.new_code_cell("# Your answer here")
        notebook.cells.append(code_cell)
        
    # Add coding questions
    notebook.cells.append(nbformat.v4.new_markdown_cell("### Coding Questions:"))
    for coding_question in section_coding_questions:
        notebook.cells.append(nbformat.v4.new_markdown_cell(coding_question))
        
        code_cell = nbformat.v4.new_code_cell("# Your answer here")
        notebook.cells.append(code_cell)

# Save the notebook to a file
file_path = "advanced_python_interview_questions.ipynb"
with open(file_path, "w") as f:
    nbformat.write(notebook, f)

print(f"Jupyter notebook file created: {file_path}")
# Out:
# Jupyter notebook file created: advanced_python_interview_questions.ipynb
